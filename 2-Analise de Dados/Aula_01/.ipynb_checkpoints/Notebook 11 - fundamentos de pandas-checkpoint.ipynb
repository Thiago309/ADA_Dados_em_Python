# %% [markdown]
# # Aula 11 - fundamentos de Pandas
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Fundamentos de Pandas
#
# _____________
#
# ### Problema gerador: processando notas de alunos.
#
# Aprenderemos na aula de hoje como trabalhar com **dados tabulares** em Python de maneira muito eficiente e intuitiva: utilizando o famoso Pandas!

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 1) Pandas
#
# O pandas é uma das bibliotecas mais usadas em data science.
#
# Seu objetivo é a **leitura, processamento e manipulação de dados** na forma de tabelas chamdas de **"DataFrame"**
#
# Antes de conhecer o Pandas, vamos ler o arquivo csv `alunos.csv`, da forma como aprendemos na aula de arquivos

# %%
import csv

f = open("alunos.csv", "r", encoding="utf-8")

leitor = csv.reader(f, delimiter=';', lineterminator='\n')

planilha = []

for linha in leitor:
    
    planilha.append(linha)
    
f.close()

planilha
# Out:
# [['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4'],
#  ['110201', 'Antonio Carlos', '20', '6.5', '8.5', '7', '6'],
#  ['110212', 'Ana Beatriz', '20', '7', '7', '7', '8'],
#  ['110218', 'Carlos Vernes', '17', '7', '7', '7', '7'],
#  ['110307', 'Francisco Cunha', '20', '9', '8.5', '8.5', '10'],
#  ['110275', 'Sandra Rosa', '15', '6.5', '7.5', '7', '7'],
#  ['110281', 'Juliana Arruda', '18', '7.5', '7', '7.5', '8'],
#  ['110301', 'Joao Galo', '20', '5', '6.5', '7', '5'],
#  ['110263', 'José Valente', '20', '10', '10', '10', '10'],
#  ['110271', 'Maria Ferreira', '19', '9.5', '8', '7', '10'],
#  ['110236', 'Adriana Tavares', '20', '8', '8', '8', '8']]

# %%
with open("alunos.csv", "r", encoding="utf-8") as f:

    planilha = [linha for linha in csv.reader(f, delimiter=';', lineterminator='\n')]

planilha
# Out:
# [['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4'],
#  ['110201', 'Antonio Carlos', '20', '6.5', '8.5', '7', '6'],
#  ['110212', 'Ana Beatriz', '20', '7', '7', '7', '8'],
#  ['110218', 'Carlos Vernes', '17', '7', '7', '7', '7'],
#  ['110307', 'Francisco Cunha', '20', '9', '8.5', '8.5', '10'],
#  ['110275', 'Sandra Rosa', '15', '6.5', '7.5', '7', '7'],
#  ['110281', 'Juliana Arruda', '18', '7.5', '7', '7.5', '8'],
#  ['110301', 'Joao Galo', '20', '5', '6.5', '7', '5'],
#  ['110263', 'José Valente', '20', '10', '10', '10', '10'],
#  ['110271', 'Maria Ferreira', '19', '9.5', '8', '7', '10'],
#  ['110236', 'Adriana Tavares', '20', '8', '8', '8', '8']]

# %% [markdown]
# Como fizemos na aula, uma vez lido o arquivo, é possível processá-lo de diversas maneiras.
#
# Por exemplo, para obter **a primeira coluna**, isto é, os nomes, fazemos:

# %%
[item[1] for item in planilha]
# Out:
# ['Nome',
#  'Antonio Carlos',
#  'Ana Beatriz',
#  'Carlos Vernes',
#  'Francisco Cunha',
#  'Sandra Rosa',
#  'Juliana Arruda',
#  'Joao Galo',
#  'José Valente',
#  'Maria Ferreira',
#  'Adriana Tavares']

# %% [markdown]
# Agora, vamos usar o Pandas e aprender uma forma muito mais natural de processar dados!

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in e:\arquivos de programas hd\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\arquivos de programas hd\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\arquivos de programas hd\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\arquivos de programas hd\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in e:\arquivos de programas hd\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in e:\arquivos de programas hd\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
df = pd.read_csv("alunos.csv", sep=";")

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %% [markdown]
# Podemos **acessar os valores nas colunas** pelo nome delas:

# %%
df["Nome"]
# Out:
# 0     Antonio Carlos
# 1        Ana Beatriz
# 2      Carlos Vernes
# 3    Francisco Cunha
# 4        Sandra Rosa
# 5     Juliana Arruda
# 6          Joao Galo
# 7       José Valente
# 8     Maria Ferreira
# 9    Adriana Tavares
# Name: Nome, dtype: object

# %%
df.columns
# Out:
# Index(['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4'], dtype='object')

# %%
df["Frequencia"]
# Out:
# 0    20
# 1    20
# 2    17
# 3    20
# 4    15
# 5    18
# 6    20
# 7    20
# 8    19
# 9    20
# Name: Frequencia, dtype: int64

# %%
df["Prova_4"]
# Out:
# 0     6
# 1     8
# 2     7
# 3    10
# 4     7
# 5     8
# 6     5
# 7    10
# 8    10
# 9     8
# Name: Prova_4, dtype: int64

# %% [markdown]
# Se quisermos obter uma lista propriamente com os valores na coluna, usamos o método `tolist()`:

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Nome"])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %%
df["Nome"]
# Out:
# 0     Antonio Carlos
# 1        Ana Beatriz
# 2      Carlos Vernes
# 3    Francisco Cunha
# 4        Sandra Rosa
# 5     Juliana Arruda
# 6          Joao Galo
# 7       José Valente
# 8     Maria Ferreira
# 9    Adriana Tavares
# Name: Nome, dtype: object

# %%
df["Nome"].tolist()
# Out:
# ['Antonio Carlos',
#  'Ana Beatriz',
#  'Carlos Vernes',
#  'Francisco Cunha',
#  'Sandra Rosa',
#  'Juliana Arruda',
#  'Joao Galo',
#  'José Valente',
#  'Maria Ferreira',
#  'Adriana Tavares']

# %% [markdown]
# Dá pra **selecionar apenas algumas colunas** do dataframe (ou seja, criando um sub-dataframe):

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %%
df2 = df[["Nome", "Frequencia"]]

# %%
df2
# Out:
#               Nome  Frequencia
# 0   Antonio Carlos          20
# 1      Ana Beatriz          20
# 2    Carlos Vernes          17
# 3  Francisco Cunha          20
# 4      Sandra Rosa          15
# 5   Juliana Arruda          18
# 6        Joao Galo          20
# 7     José Valente          20
# 8   Maria Ferreira          19
# 9  Adriana Tavares          20

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %% [markdown]
# É possível **alterar valores** da tabela. Para isso, primeiro localizamos o valor a ser alterado com o **.loc**, passando a linha e coluna correspondente, e depois atribuímos o novo valor

# %%
df.loc[2]
# Out:
# RA                   110218
# Nome          Carlos Vernes
# Frequencia               17
# Prova_1                 7.0
# Prova_2                 7.0
# Prova_3                 7.0
# Prova_4                   7
# Name: 2, dtype: object

# %%
df.loc[2, "Prova_3"] = 8.5

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      8.5        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %% [markdown]
# **Criando uma coluna nova**, com todas as linhas preenchidas com o mesmo valor

# %%
df["qqr_coisa"] = "ADA"

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      8.5        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8
#
#   qqr_coisa  Prova_5
# 0       ADA        2
# 1       ADA        9
# 2       ADA        4
# 3       ADA       10
# 4       ADA        1
# 5       ADA        6
# 6       ADA        1
# 7       ADA        0
# 8       ADA        7
# 9       ADA        2

# %%
import random

# %%
df.columns
# Out:
# Index(['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4',
#        'qqr_coisa'],
#       dtype='object')

# %%
df.shape[0] # retorna o numero de linhas da coluna RA existentes em uma tabela.
# Out:
# 10

# %%
df.shape # retorna o numero de linhas e colunas existentes na tabela.
# Out:
# (10, 9)

# %%
df["Prova_5"] = [random.randint(0, 10) for _ in range(df.shape[0])]

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      8.5        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8
#
#   qqr_coisa  Prova_5
# 0       ADA        1
# 1       ADA        7
# 2       ADA        9
# 3       ADA        0
# 4       ADA        4
# 5       ADA        6
# 6       ADA        7
# 7       ADA        8
# 8       ADA        7
# 9       ADA        7

# %% [markdown]
# Também é possível **criar uma linha nova**:

# %%
df.loc[10, "RA"] = 110237
df.loc[10, "Nome"] = "Han Solo"
df.loc[10, "Frequencia"] = 75
df.loc[10, "Prova_1"] = 10
df.loc[10, "Prova_2"] = 8.2

# %%
df
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média
# 0      1.0    5.8
# 1      7.0    7.2
# 2      9.0    7.7
# 3      0.0    7.2
# 4      4.0    6.4
# 5      6.0    7.2
# 6      7.0    6.1
# 7      8.0    9.6
# 8      7.0    8.3
# 9      7.0    7.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RA          10 non-null     float64
#  1   Nome        10 non-null     object
#  2   Frequencia  10 non-null     float64
#  3   Prova_1     10 non-null     float64
#  4   Prova_2     10 non-null     float64
#  5   Prova_3     10 non-null     float64
#  6   Prova_4     10 non-null     float64
#  7   Prova_5     10 non-null     float64
#  8   média       10 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 852.0+ bytes

# %% [markdown]
# Podemos também excluir qualquer colunas que desejamos ! Veja o exemplo a baixo.

# %%
df = df.drop(columns=["qqr_coisa"])

# Ambas linhas de comandos fazem a mesma função...

# df.drop(columns=["qqr_coisa"], inplace=True)

# %%
df
# Out:
#           RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0   110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1   110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2   110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3   110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4   110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5   110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6   110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7   110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8   110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9   110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
# 10  110237.0         Han Solo        75.0     10.0      8.2      NaN      NaN
#
#     Prova_5
# 0       1.0
# 1       7.0
# 2       9.0
# 3       0.0
# 4       4.0
# 5       6.0
# 6       7.0
# 7       8.0
# 8       7.0
# 9       7.0
# 10      NaN

# %%
df = df.drop(index=[10])

# %%
df
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5
# 0      1.0
# 1      7.0
# 2      9.0
# 3      0.0
# 4      4.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      7.0
# 9      7.0

# %% [markdown]
# Podemos fazer operações entre os valores das colunas, e criar com isso novas colunas!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RA          10 non-null     float64
#  1   Nome        10 non-null     object
#  2   Frequencia  10 non-null     float64
#  3   Prova_1     10 non-null     float64
#  4   Prova_2     10 non-null     float64
#  5   Prova_3     10 non-null     float64
#  6   Prova_4     10 non-null     float64
#  7   Prova_5     10 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 772.0+ bytes

# %%
df["média"] = (df["Prova_1"] + df["Prova_2"] + df["Prova_3"] + df["Prova_4"] + df["Prova_5"])/5

# %%
df
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média
# 0      1.0    5.8
# 1      7.0    7.2
# 2      9.0    7.7
# 3      0.0    7.2
# 4      4.0    6.4
# 5      6.0    7.2
# 6      7.0    6.1
# 7      8.0    9.6
# 8      7.0    8.3
# 9      7.0    7.8

# %% [markdown]
# Também há algumas funções prontas:

# %%
df.columns
# Out:
# Index(['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4',
#        'Prova_5', 'média'],
#       dtype='object')

# %%
df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4', 'Prova_5']]
# Out:
#    Prova_1  Prova_2  Prova_3  Prova_4  Prova_5
# 0      6.5      8.5      7.0      6.0      1.0
# 1      7.0      7.0      7.0      8.0      7.0
# 2      7.0      7.0      8.5      7.0      9.0
# 3      9.0      8.5      8.5     10.0      0.0
# 4      6.5      7.5      7.0      7.0      4.0
# 5      7.5      7.0      7.5      8.0      6.0
# 6      5.0      6.5      7.0      5.0      7.0
# 7     10.0     10.0     10.0     10.0      8.0
# 8      9.5      8.0      7.0     10.0      7.0
# 9      8.0      8.0      8.0      8.0      7.0

# %%
'''Mede as medias das colunas. A variavel axis indica o grau de inclinação que a media realizara as medias. 
   Neste caso zero(0) significa colunas.'''
df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4', 'Prova_5']].mean(axis=0)
# Out:
# Prova_1    7.60
# Prova_2    7.80
# Prova_3    7.75
# Prova_4    7.90
# Prova_5    5.60
# dtype: float64

# %%
df["média"] = (df["Prova_1"] + df["Prova_2"] + df["Prova_3"] + df["Prova_4"] + df["Prova_5"])/5

# %%
df.columns
# Out:
# Index(['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4',
#        'Prova_5', 'média'],
#       dtype='object')

# %%
[col for col in df.columns if "Prova_" in col]
# Out:
# ['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4', 'Prova_5']

# %%
'''Mede as medias das colunas. A variavel axis indica o grau de inclinação que a media realizara as medias. 
   Neste caso um(1) significa linhas.'''

df["média2"] = df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4', 'Prova_5']].mean(axis=1)

df["média3"] = df[[col for col in df.columns if "Prova_" in col]].mean(axis=1)

# %%
df
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média  média2  média3
# 0      1.0    5.8     5.8     5.8
# 1      7.0    7.2     7.2     7.2
# 2      9.0    7.7     7.7     7.7
# 3      0.0    7.2     7.2     7.2
# 4      4.0    6.4     6.4     6.4
# 5      6.0    7.2     7.2     7.2
# 6      7.0    6.1     6.1     6.1
# 7      8.0    9.6     9.6     9.6
# 8      7.0    8.3     8.3     8.3
# 9      7.0    7.8     7.8     7.8

# %% [markdown]
# Naturalmente, o resultado é o mesmo!

# %% [markdown]
# Podemos **fazer filtros** muito facilmente
#
# Basta explicitarmos **condições sobre os valores das colunas**, e utilizar isso como indexador do dataframe!

# %%
mascara = df["média"] > 8

# %%
df[mascara]
# Out:
#          RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 7  110263.0    José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0  Maria Ferreira        19.0      9.5      8.0      7.0     10.0
#
#    Prova_5  média  média2  média3
# 7      8.0    9.6     9.6     9.6
# 8      7.0    8.3     8.3     8.3

# %%
df[df["média"]>8]
# Out:
#          RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 7  110263.0    José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0  Maria Ferreira        19.0      9.5      8.0      7.0     10.0
#
#    Prova_5  média  média2  média3
# 7      8.0    9.6     9.6     9.6
# 8      7.0    8.3     8.3     8.3

# %% [markdown]
# Se quisermos fazer filtros mais complexos (filtros compostos, em mais de uma coluna), podemos fazer **conjunções entre filtros**, utilizando os **operadores lógicos de conjunção**.
#
# Obs.: temos os seguintes operadores lógicos:
#
# - &     - corresponde ao "and"
# - |     - corresponde ao "or"
# - ~     - corresponde ao "not"

# %%
(df["média"]>7)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: média, dtype: bool

# %%
(df["Frequencia"]<20)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Frequencia, dtype: bool

# %%
df[(df["média"]>7) & (df["Frequencia"]<20)]
# Out:
#          RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 2  110218.0   Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 5  110281.0  Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 8  110271.0  Maria Ferreira        19.0      9.5      8.0      7.0     10.0
#
#    Prova_5  média  média2  média3
# 2      9.0    7.7     7.7     7.7
# 5      6.0    7.2     7.2     7.2
# 8      7.0    8.3     8.3     8.3

# %%
df[~((df["média"]>7) & (df["Frequencia"]<20))]
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média  média2  média3
# 0      1.0    5.8     5.8     5.8
# 1      7.0    7.2     7.2     7.2
# 3      0.0    7.2     7.2     7.2
# 4      4.0    6.4     6.4     6.4
# 6      7.0    6.1     6.1     6.1
# 7      8.0    9.6     9.6     9.6
# 9      7.0    7.8     7.8     7.8

# %%
df[(df["média"]>7) | (df["Frequencia"]<20)]
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média  média2  média3
# 1      7.0    7.2     7.2     7.2
# 2      9.0    7.7     7.7     7.7
# 3      0.0    7.2     7.2     7.2
# 4      4.0    6.4     6.4     6.4
# 5      6.0    7.2     7.2     7.2
# 7      8.0    9.6     9.6     9.6
# 8      7.0    8.3     8.3     8.3
# 9      7.0    7.8     7.8     7.8

# %% [markdown]
# Uma outra forma bem simples de fazer filtros e com o método `query()`, que permite que passemos uma expressão lógica na forma de uma string:

# %%
df[(df["média"]>7) & (df["Frequencia"]<20)]
# Out:
#          RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 2  110218.0   Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 5  110281.0  Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 8  110271.0  Maria Ferreira        19.0      9.5      8.0      7.0     10.0
#
#    Prova_5  média  média2  média3
# 2      9.0    7.7     7.7     7.7
# 5      6.0    7.2     7.2     7.2
# 8      7.0    8.3     8.3     8.3

# %%
df.query("média > 7 and Frequencia < 20")
# Out:
#          RA            Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 2  110218.0   Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 5  110281.0  Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 8  110271.0  Maria Ferreira        19.0      9.5      8.0      7.0     10.0
#
#    Prova_5  média  média2  média3
# 2      9.0    7.7     7.7     7.7
# 5      6.0    7.2     7.2     7.2
# 8      7.0    8.3     8.3     8.3

# %% [markdown]
# ________

# %% [markdown]
# E também é bem fácil salvar um dataframe de volta pra CSV ou pro Excel:

# %%
df
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média  média2  média3
# 0      1.0    5.8     5.8     5.8
# 1      7.0    7.2     7.2     7.2
# 2      9.0    7.7     7.7     7.7
# 3      0.0    7.2     7.2     7.2
# 4      4.0    6.4     6.4     6.4
# 5      6.0    7.2     7.2     7.2
# 6      7.0    6.1     6.1     6.1
# 7      8.0    9.6     9.6     9.6
# 8      7.0    8.3     8.3     8.3
# 9      7.0    7.8     7.8     7.8

# %%
# index = False, retira os id da tabela que será salvo no arquivo CSV.

df.to_csv("notas_processadas.csv", sep=";", index=False)

# salvando a tabela juntos com os indices.
# df.to_csv("notas_processadas.csv", sep=";")

# %%
df_filtrado = df.query("média > 7 and Frequencia < 20")

df_filtrado.to_csv("notas_filtrado.csv", sep=";", index=False)

# %%
df_filtrado.to_excel("notas_filtrado.xlsx")

# %% [markdown]
# Agora que entendemos na prática como usar o Pandas, vamos nos aprofundar um pouco mais em sua estrutura!

# %% [markdown]
# O DataFrame é a estrutura que se assemelha a uma tabela/planilha, como vimos acima.
#
# Ao ler um arquivo, um dataframe é criado automaticamente pelo pandas!
#
# Por debaixo dos panos, o dataframe é representado por um dicionário em que a **chave** é o **nome da coluna** e os **valores** são as **Series** (todas com mesmo índice).

# %% [markdown]
# Assim, podemos **criar um dataframe a partir de um dicionario**, usando a função `pd.DataFrame()`

# %%
cadastro = {"nomes" : ["Joãozinho", "Mariazinha"],
            "idade" : [22, 25],
            "cidade" : ["São Paulo", "Santo André"],
            "n_filhos": [0, 0],
            "altura" : [1.80, 1.65]}

cadastro
# Out:
# {'nomes': ['Joãozinho', 'Mariazinha'],
#  'idade': [22, 25],
#  'cidade': ['São Paulo', 'Santo André'],
#  'n_filhos': [0, 0],
#  'altura': [1.8, 1.65]}

# %%
pd.DataFrame(cadastro)
# Out:
#         nomes  idade       cidade  n_filhos  altura
# 0   Joãozinho     22    São Paulo         0    1.80
# 1  Mariazinha     25  Santo André         0    1.65

# %%
df
# Out:
#          RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0  110201.0   Antonio Carlos        20.0      6.5      8.5      7.0      6.0
# 1  110212.0      Ana Beatriz        20.0      7.0      7.0      7.0      8.0
# 2  110218.0    Carlos Vernes        17.0      7.0      7.0      8.5      7.0
# 3  110307.0  Francisco Cunha        20.0      9.0      8.5      8.5     10.0
# 4  110275.0      Sandra Rosa        15.0      6.5      7.5      7.0      7.0
# 5  110281.0   Juliana Arruda        18.0      7.5      7.0      7.5      8.0
# 6  110301.0        Joao Galo        20.0      5.0      6.5      7.0      5.0
# 7  110263.0     José Valente        20.0     10.0     10.0     10.0     10.0
# 8  110271.0   Maria Ferreira        19.0      9.5      8.0      7.0     10.0
# 9  110236.0  Adriana Tavares        20.0      8.0      8.0      8.0      8.0
#
#    Prova_5  média  média2  média3
# 0      1.0    5.8     5.8     5.8
# 1      7.0    7.2     7.2     7.2
# 2      9.0    7.7     7.7     7.7
# 3      0.0    7.2     7.2     7.2
# 4      4.0    6.4     6.4     6.4
# 5      6.0    7.2     7.2     7.2
# 6      7.0    6.1     6.1     6.1
# 7      8.0    9.6     9.6     9.6
# 8      7.0    8.3     8.3     8.3
# 9      7.0    7.8     7.8     7.8

# %%
df.to_dict()
# Out:
# {'RA': {0: 110201.0,
#   1: 110212.0,
#   2: 110218.0,
#   3: 110307.0,
#   4: 110275.0,
#   5: 110281.0,
#   6: 110301.0,
#   7: 110263.0,
#   8: 110271.0,
#   9: 110236.0},
#  'Nome': {0: 'Antonio Carlos',
#   1: 'Ana Beatriz',
#   2: 'Carlos Vernes',
#   3: 'Francisco Cunha',
#   4: 'Sandra Rosa',
#   5: 'Juliana Arruda',
#   6: 'Joao Galo',
#   7: 'José Valente',
#   8: 'Maria Ferreira',
#   9: 'Adriana Tavares'},
#  'Frequencia': {0: 20.0,
#   1: 20.0,
#   2: 17.0,
#   3: 20.0,
#   4: 15.0,
#   5: 18.0,
#   6: 20.0,
#   7: 20.0,
#   8: 19.0,
#   9: 20.0},
#  'Prova_1': {0: 6.5,
#   1: 7.0,
#   2: 7.0,
#   3: 9.0,
#   4: 6.5,
#   5: 7.5,
#   6: 5.0,
#   7: 10.0,
#   8: 9.5,
#   9: 8.0},
#  'Prova_2': {0: 8.5,
#   1: 7.0,
#   2: 7.0,
#   3: 8.5,
#   4: 7.5,
#   5: 7.0,
#   6: 6.5,
#   7: 10.0,
#   8: 8.0,
#   9: 8.0},
#  'Prova_3': {0: 7.0,
#   1: 7.0,
#   2: 8.5,
#   3: 8.5,
#   4: 7.0,
#   5: 7.5,
#   6: 7.0,
#   7: 10.0,
#   8: 7.0,
#   9: 8.0},
#  'Prova_4': {0: 6.0,
#   1: 8.0,
#   2: 7.0,
#   3: 10.0,
#   4: 7.0,
#   5: 8.0,
#   6: 5.0,
#   7: 10.0,
#   8: 10.0,
#   9: 8.0},
#  'Prova_5': {0: 1.0,
#   1: 7.0,
#   2: 9.0,
#   3: 0.0,
#   4: 4.0,
#   5: 6.0,
#   6: 7.0,
#   7: 8.0,
#   8: 7.0,
#   9: 7.0},
#  'média': {0: 5.8,
#   1: 7.2,
#   2: 7.7,
#   3: 7.2,
#   4: 6.4,
#   5: 7.2,
#   6: 6.1,
#   7: 9.6,
#   8: 8.3,
#   9: 7.8},
#  'média2': {0: 5.8,
#   1: 7.2,
#   2: 7.7,
#   3: 7.2,
#   4: 6.4,
#   5: 7.2,
#   6: 6.1,
#   7: 9.6,
#   8: 8.3,
#   9: 7.8},
#  'média3': {0: 5.8,
#   1: 7.2,
#   2: 7.7,
#   3: 7.2,
#   4: 6.4,
#   5: 7.2,
#   6: 6.1,
#   7: 9.6,
#   8: 8.3,
#   9: 7.8}}

# %% [markdown]
# Mas, como vimos, podemos também ler um dataframe a partir de um arquivo, que é a forma mais comum de trabalharmos com o pandas!
